# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df_BookRatings=pd.read_csv('BX-Book-Ratings.csv',sep=';',error_bad_lines=False,encoding='latin-1')
df_Books=pd.read_csv('BX-Books.csv',sep=';',error_bad_lines=False,encoding='latin-1')
df_Users=pd.read_csv('BX-Users.csv',sep=';',error_bad_lines=False,encoding='latin-1')
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'

# %%
df_BookRatings.shape
# Out:
# (1149780, 3)

# %%
df_Books.shape
# Out:
# (271360, 8)

# %%
df_Users.shape
# Out:
# (278858, 3)

# %%
df_BookRatings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df_Books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
df_Users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
df=df_BookRatings.merge(df_Books,on='ISBN')

# %%
df.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
df=df.drop(columns=['Image-URL-S','Image-URL-M','Image-URL-L'],axis=1)

# %%
df=pd.merge(df,df_Users,on='User-ID')

# %%
df.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1     2313  034545104X            5
# 2     2313  0812533550            9
# 3     2313  0679745580            8
# 4     2313  0060173289            9
#
#                                          Book-Title       Book-Author  \
# 0                              Flesh Tones: A Novel        M. J. Rose
# 1                              Flesh Tones: A Novel        M. J. Rose
# 2     Ender's Game (Ender Wiggins Saga (Paperback))  Orson Scott Card
# 3             In Cold Blood (Vintage International)     TRUMAN CAPOTE
# 4  Divine Secrets of the Ya-Ya Sisterhood : A Novel     Rebecca Wells
#
#   Year-Of-Publication         Publisher               Location   Age
# 0                2002  Ballantine Books      tyler, texas, usa   NaN
# 1                2002  Ballantine Books  cincinnati, ohio, usa  23.0
# 2                1986         Tor Books  cincinnati, ohio, usa  23.0
# ...

# %%
#Rating plot.
sns.countplot(df['Book-Rating'])
plt.show()

# %%
#Segragating implicit and explict ratings datasets
ratings_explicit = df[df['Book-Rating'] != 0]
ratings_implicit = df[df['Book-Rating']== 0]

# %%
ratings_implicit.head()
# Out:
#     User-ID        ISBN  Book-Rating                               Book-Title  \
# 0    276725  034545104X            0                     Flesh Tones: A Novel
# 9      2313  0449912558            0                              The Sparrow
# 12     2313  0300069049            0  Cosima Wagner's Diaries: An Abridgement
# 16     2313  0375706771            0                        Midwives: A Novel
# 21     2313  0451525078            0                 Don Quixote of LA Mancha
#
#                      Book-Author Year-Of-Publication              Publisher  \
# 0                     M. J. Rose                2002       Ballantine Books
# 9             MARY DORIA RUSSELL                1997          Fawcett Books
# 12                 Cosima Wagner                1997  Yale University Press
# 16               Chris Bohjalian                1998                Vintage
# 21  Miguel de Cervantes Saavedra                1990        Signet Classics
#
#                  Location   Age
# ...

# %%
print(ratings_explicit.shape)
print(ratings_implicit.shape)
# Out:
# (383842, 9)
# (647294, 9)

# %%
counts1=ratings_explicit['User-ID'].value_counts()
ratings_explicit=ratings_explicit[ratings_explicit['User-ID'].isin(counts1[counts1>100].index)]
counts=ratings_explicit['Book-Rating'].value_counts()
ratings_explicit=ratings_explicit[ratings_explicit['Book-Rating'].isin(counts[counts>100].index)]

# %%
piv_explicit=ratings_explicit.pivot(index='User-ID',columns='ISBN',values='Book-Rating')

# %%
piv_explicit.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-312cba35c94f> in <module>
# ----> 1 piv_explicit.head()
#
# NameError: name 'piv_explicit' is not defined

# %%
isbn=piv_explicit.corrwith(piv_explicit['B00009NDAN'])
isbn.head()

# %%
df.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1     2313  034545104X            5
# 2     2313  0812533550            9
# 3     2313  0679745580            8
# 4     2313  0060173289            9
#
#                                          Book-Title       Book-Author  \
# 0                              Flesh Tones: A Novel        M. J. Rose
# 1                              Flesh Tones: A Novel        M. J. Rose
# 2     Ender's Game (Ender Wiggins Saga (Paperback))  Orson Scott Card
# 3             In Cold Blood (Vintage International)     TRUMAN CAPOTE
# 4  Divine Secrets of the Ya-Ya Sisterhood : A Novel     Rebecca Wells
#
#   Year-Of-Publication         Publisher               Location   Age
# 0                2002  Ballantine Books      tyler, texas, usa   NaN
# 1                2002  Ballantine Books  cincinnati, ohio, usa  23.0
# 2                1986         Tor Books  cincinnati, ohio, usa  23.0
# ...

# %%
isbn=np.array(df['ISBN'].replace(regex=True,inplace=True,to_replace=r'\D',value=r''))

# %%
df['User-ID'].head()
# Out:
# 0    276725
# 1      2313
# 2      2313
# 3      2313
# 4      2313
# Name: User-ID, dtype: int64

# %%
#df['ISBN'].dtype,df['User-ID'].dtype
#df.head()
df['ISBN']=df['ISBN'].astype(np.int64)
df.head()
# Out:
#    User-ID       ISBN  Book-Rating  \
# 0   276725   34545104            0
# 1     2313   34545104            5
# 2     2313  812533550            9
# 3     2313  679745580            8
# 4     2313   60173289            9
#
#                                          Book-Title       Book-Author  \
# 0                              Flesh Tones: A Novel        M. J. Rose
# 1                              Flesh Tones: A Novel        M. J. Rose
# 2     Ender's Game (Ender Wiggins Saga (Paperback))  Orson Scott Card
# 3             In Cold Blood (Vintage International)     TRUMAN CAPOTE
# 4  Divine Secrets of the Ya-Ya Sisterhood : A Novel     Rebecca Wells
#
#   Year-Of-Publication         Publisher               Location   Age
# 0                2002  Ballantine Books      tyler, texas, usa   NaN
# 1                2002  Ballantine Books  cincinnati, ohio, usa  23.0
# 2                1986         Tor Books  cincinnati, ohio, usa  23.0
# ...

# %%
#userid.shape,isbn.shape
df.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1     2313  034545104X            5
# 2     2313  0812533550            9
# 3     2313  0679745580            8
# 4     2313  0060173289            9
#
#                                          Book-Title       Book-Author  \
# 0                              Flesh Tones: A Novel        M. J. Rose
# 1                              Flesh Tones: A Novel        M. J. Rose
# 2     Ender's Game (Ender Wiggins Saga (Paperback))  Orson Scott Card
# 3             In Cold Blood (Vintage International)     TRUMAN CAPOTE
# 4  Divine Secrets of the Ya-Ya Sisterhood : A Novel     Rebecca Wells
#
#   Year-Of-Publication         Publisher               Location   Age
# 0                2002  Ballantine Books      tyler, texas, usa   NaN
# 1                2002  Ballantine Books  cincinnati, ohio, usa  23.0
# 2                1986         Tor Books  cincinnati, ohio, usa  23.0
# ...

# %%
from scipy import sparse
# scipy expects the data in (value_column, (x, y))
mat = sparse.coo_matrix((df["Book-Rating"], (df["User-ID"], df["ISBN"])))

# %%
print(mat)
# Out:
#   (276725, 34545104)	0
#   (2313, 34545104)	5
#   (2313, 812533550)	9
#   (2313, 679745580)	8
#   (2313, 60173289)	9
#   (2313, 385482388)	5
#   (2313, 399146431)	5
#   (2313, 345348036)	9
#   (2313, 553278223)	7
#   (2313, 449912558)	0
#   (2313, 20442602)	9
#   (2313, 295955252)	8
#   (2313, 300069049)	0
#   (2313, 312186754)	5
#   (2313, 312275560)	6
#   (2313, 312876513)	6
#   (2313, 375706771)	0
#   (2313, 385470142)	9
#   (2313, 394756827)	10
#   (2313, 395874653)	8
#   (2313, 399141146)	3
#   (2313, 451525078)	0
#   (2313, 452260116)	9
#   (2313, 520077806)	8
#   (2313, 553213601)	0
#   :	:
#   (275717, 8401322677)	7
#   (275863, 70084998)	0
#   (275863, 159244086)	0
#   (275874, 300059566)	7
#   (275874, 223405155)	0
#   (275892, 3570005941)	7
#   (275901, 3250600261)	0
#   (275944, 3570260941)	0
#   (276001, 395669561)	0
#   (276047, 747503818)	0
#   (276054, 738840459)	0
#   (276061, 879977086)	0
#   (276067, 694004162)	10
#   (276142, 671038672)	10
# ...

# %%
mat.shape
# Out:
# (278855, 351836547991)
