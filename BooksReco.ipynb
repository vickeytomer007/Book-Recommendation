# %%
import numpy as np
import pandas as pd

# %%
df_Ratings=pd.read_csv('BX-Book-Ratings.csv',sep=';',error_bad_lines=False,encoding='latin-1')
df_Books=pd.read_csv('BX-Books.csv',sep=';',error_bad_lines=False,encoding='latin-1')
df_User=pd.read_csv('BX-Users.csv',sep=';',error_bad_lines=False,encoding='latin-1')
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'
# /home/vivek/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_Ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
df_User.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
df_Books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
#df1.merge(df2,on='name').merge(df3,on='name')
df_merge=df_Books.merge(df_Ratings,on='ISBN').merge(df_User,on='User-ID')

# %%
df_merge.head(5)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L  User-ID  Book-Rating  \
# 0  http://images.amazon.com/images/P/0195153448.0...        2            0
# 1  http://images.amazon.com/images/P/0002005018.0...        8            5
# 2  http://images.amazon.com/images/P/0060973129.0...        8            0
# 3  http://images.amazon.com/images/P/0374157065.0...        8            0
# 4  http://images.amazon.com/images/P/0393045218.0...        8            0
#
#                     Location   Age
# 0  stockton, california, usa  18.0
# 1   timmins, ontario, canada   NaN
# 2   timmins, ontario, canada   NaN
# 3   timmins, ontario, canada   NaN
# 4   timmins, ontario, canada   NaN

# %%
#Remove extra columns that are of no use for recommendation.
df_merge.drop(['Image-URL-S','Image-URL-M','Image-URL-L'],axis=1,inplace=True)

# %%
df_merge.head(5)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#    User-ID  Book-Rating                   Location   Age
# 0        2            0  stockton, california, usa  18.0
# 1        8            5   timmins, ontario, canada   NaN
# 2        8            0   timmins, ontario, canada   NaN
# 3        8            0   timmins, ontario, canada   NaN
# 4        8            0   timmins, ontario, canada   NaN

# %%
#Grouped data on the basis of title ratings.
df_merge.groupby('Book-Title')['Book-Rating'].mean().sort_values(ascending=False).head()
# Out:
# Book-Title
# Civil Rights Actions: Enforcing the Constitution (University Casebook)                                              10.0
# FAR/AIM 2004: Federal Aviation Regulations/Aeronautical Information Manual (FAR series)                             10.0
# What Followers Expect from Leaders : How to Meet People's Expectations and Build Credibility (Management Series)    10.0
# FAR/AIM 2003: Federal Aviation Regulations/Aeronautical Information Manual (FAR series)                             10.0
# Lewis and Clark: Voyage of Discovery (Voyage of Discovery)                                                          10.0
# Name: Book-Rating, dtype: float64

# %%
ratings=pd.DataFrame(df_merge.groupby('Book-Title')['Book-Rating'].mean())

# %%
ratings['num of ratings']=df_merge.groupby('Book-Title')['Book-Rating'].count()

# %%
ratings.head(5)
# Out:
#                                                     Book-Rating  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...         2.25
#  Always Have Popsicles                                     0.00
#  Apple Magic (The Collector's series)                      0.00
#  Ask Lily (Young Women of Faith: Lily Series, B...         8.00
#  Beyond IBM: Leadership Marketing and Finance f...         0.00
#
#                                                     num of ratings
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...               4
#  Always Have Popsicles                                           1
#  Apple Magic (The Collector's series)                            1
#  Ask Lily (Young Women of Faith: Lily Series, B...               1
#  Beyond IBM: Leadership Marketing and Finance f...               1

# %%
Books_reco=df_merge.head(30000).pivot_table(index='User-ID',columns='Book-Title',values='Book-Rating')
#df_merge.info()

# %%
Books_reco.head(5)
# Out:
# Book-Title   Good Wives: Image and Reality in the Lives of Women in Northern New England, 1650-1750  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     NaN
#
# Book-Title   LA Gallinita Roja/the Little Red Hen  \
# User-ID
# 2                                             NaN
# 8                                             NaN
# 2954                                          NaN
# 11400                                         NaN
# 11676                                         NaN
#
# Book-Title   Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     0.0
#
# Book-Title  !Arriba! Comunicacion y cultura  !Yo!  \
# User-ID
# 2                                       NaN   NaN
# 8                                       NaN   NaN
# 2954                                    NaN   NaN
# 11400                                   NaN   NaN
# 11676                                   NaN   NaN
#
# Book-Title  'A Hell of a Place to Lose a Cow': An American Hitchhiking Odyssey  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     NaN
#
# Book-Title  'Eine gute Frau hat keinen Kopf'. EuropÃ?Â¤ische SprichwÃ?Â¶rter Ã?Â¼ber Frauen.  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     2.0
#
# Book-Title  'Til We Meet Again (The Circle) (Silhouette Shadows, No 60)  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     NaN
#
# Book-Title  'Twas the Night Before Christmas  \
# User-ID
# 2                                        NaN
# 8                                        NaN
# 2954                                     NaN
# 11400                                    NaN
# 11676                                    NaN
#
# Book-Title  'night, Mother : A Play (Mermaid Dramabook)      ...        \
# User-ID                                                      ...
# 2                                                   NaN      ...
# 8                                                   NaN      ...
# 2954                                                NaN      ...
# 11400                                               NaN      ...
# 11676                                               NaN      ...
#
# Book-Title  schÃ?Â¶ner wohnen.doc. Ein WG- Roman.  stardust  \
# User-ID
# 2                                             NaN       NaN
# 8                                             NaN       NaN
# 2954                                          NaN       NaN
# 11400                                         NaN       NaN
# 11676                                         7.0       8.0
#
# Book-Title  street bible, the  wet sand, raven tracks  \
# User-ID
# 2                         NaN                     NaN
# 8                         NaN                     NaN
# 2954                      NaN                     NaN
# 11400                     NaN                     NaN
# 11676                     9.0                     8.0
#
# Book-Title  whataboutrick.com: a poetic tribute to Richard A. Ricci  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     5.0
#
# Book-Title  Â¡Corre, perro, corre!  Â¿QuÃ© me quieres, amor?  \
# User-ID
# 2                              NaN                       NaN
# 8                              NaN                       NaN
# 2954                           NaN                       NaN
# 11400                          NaN                       NaN
# 11676                         10.0                       0.0
#
# Book-Title  Ã?Â?ber das Fernsehen.  \
# User-ID
# 2                              NaN
# 8                              NaN
# 2954                           NaN
# 11400                          NaN
# 11676                          8.0
#
# Book-Title  Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.  Ã?Â?lpiraten.
# User-ID
# 2                                                         NaN              NaN
# 8                                                         NaN              NaN
# 2954                                                      NaN              NaN
# 11400                                                     NaN              NaN
# 11676                                                     0.0              0.0
#
# [5 rows x 23137 columns]

# %%
Novel=Books_reco['1st to Die: A Novel']

# %%
Novel.head()
# Out:
# User-ID
# 2        NaN
# 8        NaN
# 2954     NaN
# 11400    NaN
# 11676    9.0
# Name: 1st to Die: A Novel, dtype: float64

# %%
similar_to_Novel=Books_reco.corrwith(Novel)
# Out:
# /home/vivek/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/vivek/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
Books_reco.head()
# Out:
# Book-Title   Good Wives: Image and Reality in the Lives of Women in Northern New England, 1650-1750  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     NaN
#
# Book-Title   LA Gallinita Roja/the Little Red Hen  \
# User-ID
# 2                                             NaN
# 8                                             NaN
# 2954                                          NaN
# 11400                                         NaN
# 11676                                         NaN
#
# Book-Title   Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     0.0
#
# Book-Title  !Arriba! Comunicacion y cultura  !Yo!  \
# User-ID
# 2                                       NaN   NaN
# 8                                       NaN   NaN
# 2954                                    NaN   NaN
# 11400                                   NaN   NaN
# 11676                                   NaN   NaN
#
# Book-Title  'A Hell of a Place to Lose a Cow': An American Hitchhiking Odyssey  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     NaN
#
# Book-Title  'Eine gute Frau hat keinen Kopf'. EuropÃ?Â¤ische SprichwÃ?Â¶rter Ã?Â¼ber Frauen.  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     2.0
#
# Book-Title  'Til We Meet Again (The Circle) (Silhouette Shadows, No 60)  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     NaN
#
# Book-Title  'Twas the Night Before Christmas  \
# User-ID
# 2                                        NaN
# 8                                        NaN
# 2954                                     NaN
# 11400                                    NaN
# 11676                                    NaN
#
# Book-Title  'night, Mother : A Play (Mermaid Dramabook)      ...        \
# User-ID                                                      ...
# 2                                                   NaN      ...
# 8                                                   NaN      ...
# 2954                                                NaN      ...
# 11400                                               NaN      ...
# 11676                                               NaN      ...
#
# Book-Title  schÃ?Â¶ner wohnen.doc. Ein WG- Roman.  stardust  \
# User-ID
# 2                                             NaN       NaN
# 8                                             NaN       NaN
# 2954                                          NaN       NaN
# 11400                                         NaN       NaN
# 11676                                         7.0       8.0
#
# Book-Title  street bible, the  wet sand, raven tracks  \
# User-ID
# 2                         NaN                     NaN
# 8                         NaN                     NaN
# 2954                      NaN                     NaN
# 11400                     NaN                     NaN
# 11676                     9.0                     8.0
#
# Book-Title  whataboutrick.com: a poetic tribute to Richard A. Ricci  \
# User-ID
# 2                                                         NaN
# 8                                                         NaN
# 2954                                                      NaN
# 11400                                                     NaN
# 11676                                                     5.0
#
# Book-Title  Â¡Corre, perro, corre!  Â¿QuÃ© me quieres, amor?  \
# User-ID
# 2                              NaN                       NaN
# 8                              NaN                       NaN
# 2954                           NaN                       NaN
# 11400                          NaN                       NaN
# 11676                         10.0                       0.0
#
# Book-Title  Ã?Â?ber das Fernsehen.  \
# User-ID
# 2                              NaN
# 8                              NaN
# 2954                           NaN
# 11400                          NaN
# 11676                          8.0
#
# Book-Title  Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.  Ã?Â?lpiraten.
# User-ID
# 2                                                         NaN              NaN
# 8                                                         NaN              NaN
# 2954                                                      NaN              NaN
# 11400                                                     NaN              NaN
# 11676                                                     0.0              0.0
#
# [5 rows x 23137 columns]

# %%
corr_noval=pd.DataFrame(similar_to_Novel,columns=['Correlation'])

# %%
corr_noval.head(5)
# Out:
#                                                     Correlation
# Book-Title
#  Good Wives: Image and Reality in the Lives of ...          NaN
#  LA Gallinita Roja/the Little Red Hen                       NaN
#  Murder of a Sleeping Beauty (Scumble River Mys...          NaN
# !Arriba! Comunicacion y cultura                             NaN
# !Yo!                                                        NaN

# %%
corr_noval=corr_noval.join(df_Ratings['Book-Rating'])

# %%
#corr_noval[corr_noval['Book-Rating']].sort_values('Correlation',ascending=False).head()
corr_noval
# Out:
#                                                     Correlation  Book-Rating
# Book-Title
#  Good Wives: Image and Reality in the Lives of ...          NaN          NaN
#  LA Gallinita Roja/the Little Red Hen                       NaN          NaN
#  Murder of a Sleeping Beauty (Scumble River Mys...          NaN          NaN
# !Arriba! Comunicacion y cultura                             NaN          NaN
# !Yo!                                                        NaN          NaN
# 'A Hell of a Place to Lose a Cow': An American ...          NaN          NaN
# 'Eine gute Frau hat keinen Kopf'. EuropÃ?Â¤isch...          NaN          NaN
# 'Til We Meet Again (The Circle) (Silhouette Sha...          NaN          NaN
# 'Twas the Night Before Christmas                            NaN          NaN
# 'night, Mother : A Play (Mermaid Dramabook)                 NaN          NaN
# 'til the Real Thing Comes Along                             NaN          NaN
# 01-01-00: A Novel of the Millennium                         NaN          NaN
# 01-01-00: The Novel of the Millennium                       1.0          NaN
# 1, 2, 3, Music!                                             NaN          NaN
# 1,001 Old-Time Garden Tips: Timeless Bits of Wi...          NaN          NaN
# 1,003 Great Things About Kids                               NaN          NaN
# 1,401 More Things That P*Ss Me Off                          NaN          NaN
# 10 Secrets for Success and Inner Peace                      NaN          NaN
# 10,000 Things to Praise God for                             NaN          NaN
# 100 Best-Loved Poems (Dover Thrift Editions)                NaN          NaN
# 100 Great Soup, Stew &amp; Chili Recipes                    NaN          NaN
# 100 Greatest Women                                          NaN          NaN
# 100 Years of American Newspaper Comics: An Illu...          NaN          NaN
# 1000 Play Thinks: Puzzles, Paradoxes, Illusions...          NaN          NaN
# 1000 Questions and Answers                                  NaN          NaN
# 1001 Things Everyone Should Know About African ...          NaN          NaN
# 1001 Ways to Be Romantic                                    NaN          NaN
# 1001 Ways to Save Money ... and Still Have a Da...          NaN          NaN
# 101 Back to School Jokes                                    NaN          NaN
# 101 Bug Jokes                                               NaN          NaN
# ...                                                         ...          ...
# Zum Leben erweckt.                                          NaN          NaN
# Zwei Frauen. Das Buch zum Film. Roman.                      NaN          NaN
# ZwÃ?Â¶lf.                                                   NaN          NaN
# \ Lamb to the Slaughter and Other Stories (Peng...          NaN          NaN
# \101 Things You Can Teach Your Kids About Baseb...          NaN          NaN
# \A neat desk is a sign of a sick mind\""                    NaN          NaN
# \A\" is for Alibi : A Kinsey Millhone Mystery (...          NaN          NaN
# \B\" is for burglar (A Kinsey Millhone mystery)"            NaN          NaN
# \God's Grandeur\" and Other Poems (Dover Thrift...          NaN          NaN
# \Honesty is one of the better policies\": Saxon...          NaN          NaN
# \I Come As a Brother\": A Remembrance of Illusi...          NaN          NaN
# \I Remember Laura\": Laura Ingalls Wilder"                  NaN          NaN
# \If I Die...\" : A True Story of Obsessive Love...          NaN          NaN
# \Joyce I feel like I know you\": Based on lette...          NaN          NaN
# \O\" Is for Outlaw"                                         1.0          NaN
# \Patriot Games\" and \"The Hunt for Red October\""          NaN          NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...          NaN          NaN
# e                                                           NaN          NaN
# little town on the prairie (little house) (litt...          NaN          NaN
# operation : mistletoe  (the special agents)                 NaN          NaN
# schÃ?Â¶ner wohnen.doc. Ein WG- Roman.                       NaN          NaN
# stardust                                                    NaN          NaN
# street bible, the                                           NaN          NaN
# wet sand, raven tracks                                      NaN          NaN
# whataboutrick.com: a poetic tribute to Richard ...          NaN          NaN
# Â¡Corre, perro, corre!                                      NaN          NaN
# Â¿QuÃ© me quieres, amor?                                    NaN          NaN
# Ã?Â?ber das Fernsehen.                                      NaN          NaN
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den St...          NaN          NaN
# Ã?Â?lpiraten.                                               NaN          NaN
#
# [23137 rows x 2 columns]
